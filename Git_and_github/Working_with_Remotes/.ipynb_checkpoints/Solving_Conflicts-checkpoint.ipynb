# %% [markdown]
# ## The Pull-merge-Push workflow
#
#
# IF git has some error in pushing then first git pull
#
# git pull
#
# git log -p origin/master
#
# Fix the conflict manually
#
# git log --graph --online --all
#
# ## Pushing Remote Branches
#
# git checkout -b branch-name
#
# git commit -m -a 'Allowing '
#
#
# ### push a local branch to remote repo
#
# git push -u orgin refactor
#
# ## Rebasing your Changes
#
#  Rebasing means changing the base commit that's used for our branch.
#
# git merge or git rebase command
#
# git rebase master
#
# git checkout master
#
# git merge refactor
#
# ### To delete the remote repo branch
# git push --delete origin refactor
#
# git push -d master
#
#
# ## Another rebasing example
#
# git fetch
#
# git rebase origin/master
#
# git rebase --continue
#
# ## Best practices for collaborators
#
# 1- It's a good idea to always synchronize your branches before starting any work on your own.
#
# 2- Another common practice is to try and avoid having very large changes that modify a lot of different things
#
# 3- We called out already that when working on a big change, it makes sense to have a separate feature branch.
#
# 4- To make the final merge of the feature branch easier, it makes sense to regularly merge changes made on the master branch back onto the feature branch.
#
# 5- If you need to maintain more than one version of a project at the same time, it's common practice to have the latest version of the project in the master branch and a stable version of the project on a separate branch.
#
# 6- So as a general rule, you shouldn't rebase changes that have been pushed to remote repos.
